# %% [markdown]
# ## Testing de la Red

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.optim as opt
from torch import nn as nn
from Custom_models import REDCN1, ResNet9

# %% [markdown]
# ##Carga de los entrnamientos y el set de prueba

# %%
model = ResNet9()
criterion = nn.CrossEntropyLoss()
optimizer = opt.SGD(model.parameters(), lr=0.001, momentum=0.9)


PATH = "./trained_model/Resnet9_trained.pth"

checkpoint = torch.load(PATH, map_location=torch.device("cpu"))


epoch = checkpoint["epoch"]

graphic1= checkpoint["loss_epoch"]

graphic2 = checkpoint["loss_epoch_validation"]
class_total = checkpoint["class_total"]
class_correct = checkpoint["class_correct"]


PATH2 = "./DATA/DATA.pth"

dataset = torch.load(PATH2)
classes = dataset["classes"]

model.eval()
# Out:
# ResNet9(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res1): Sequential(
#     (0): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (conv5): Sequential(
#     (0): Conv2d(512, 1028, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(1028, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res3): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1028, 1028, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(1028, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(1028, 1028, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(1028, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=1028, out_features=100, bias=True)
#   )
# )

# %% [markdown]
# ##Funcion de perdida para la Resnet9

# %%
plt.plot(graphic1, label="Train_Loss")
plt.plot(graphic2, label="Val_Loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %% [markdown]
# ## Precision de la Red global y por clases

# %%
for i in range(len(classes)):
    if class_total[i] > 0:
        print(
            f"Test Accuracy of class {classes[i]} : {float(100 * class_correct[i] / class_total[i])}% where {int(np.sum(class_correct[i]))} of {int(np.sum(class_total[i]))} were predicted correctly"
        )
    else:
        print("Test Accuracy of %5s: N/A (no training examples)" % (classes[i]))

print(
    f"\nTest Accuracy : {float(100. * np.sum(class_correct) / np.sum(class_total))}% where {int(np.sum(class_correct))} of {int(np.sum(class_total))} were predicted correctly"
)
# Out:
# Test Accuracy of class apple : 80.0% where 80 of 100 were predicted correctly
# Test Accuracy of class aquarium_fish : 71.0% where 71 of 100 were predicted correctly
# Test Accuracy of class baby : 55.0% where 55 of 100 were predicted correctly
# Test Accuracy of class bear : 30.0% where 30 of 100 were predicted correctly
# Test Accuracy of class beaver : 36.0% where 36 of 100 were predicted correctly
# Test Accuracy of class bed : 50.0% where 50 of 100 were predicted correctly
# Test Accuracy of class bee : 63.0% where 63 of 100 were predicted correctly
# Test Accuracy of class beetle : 52.0% where 52 of 100 were predicted correctly
# Test Accuracy of class bicycle : 75.0% where 75 of 100 were predicted correctly
# Test Accuracy of class bottle : 62.0% where 62 of 100 were predicted correctly
# Test Accuracy of class bowl : 39.0% where 39 of 100 were predicted correctly
# Test Accuracy of class boy : 36.0% where 36 of 100 were predicted correctly
# Test Accuracy of class bridge : 54.0% where 54 of 100 were predicted correctly
# Test Accuracy of class bus : 51.0% where 51 of 100 were predicted correctly
# Test Accuracy of class butterfly : 47.0% where 47 of 100 were predicted correctly
# Test Accuracy of class camel : 46.0% where 46 of 100 were predicted correctly
# Test Accuracy of class can : 60.0% where 60 of 100 were predicted correctly
# Test Accuracy of class castle : 74.0% where 74 of 100 were predicted correctly
# Test Accuracy of class caterpillar : 49.0% where 49 of 100 were predicted correctly
# Test Accuracy of class cattle : 47.0% where 47 of 100 were predicted correctly
# Test Accuracy of class chair : 75.0% where 75 of 100 were predicted correctly
# Test Accuracy of class chimpanzee : 79.0% where 79 of 100 were predicted correctly
# Test Accuracy of class clock : 53.0% where 53 of 100 were predicted correctly
# Test Accuracy of class cloud : 77.0% where 77 of 100 were predicted correctly
# Test Accuracy of class cockroach : 77.0% where 77 of 100 were predicted correctly
# Test Accuracy of class couch : 41.0% where 41 of 100 were predicted correctly
# Test Accuracy of class crab : 54.0% where 54 of 100 were predicted correctly
# Test Accuracy of class crocodile : 47.0% where 47 of 100 were predicted correctly
# Test Accuracy of class cup : 70.0% where 70 of 100 were predicted correctly
# Test Accuracy of class dinosaur : 51.0% where 51 of 100 were predicted correctly
# Test Accuracy of class dolphin : 54.0% where 54 of 100 were predicted correctly
# Test Accuracy of class elephant : 57.0% where 57 of 100 were predicted correctly
# Test Accuracy of class flatfish : 46.0% where 46 of 100 were predicted correctly
# Test Accuracy of class forest : 56.0% where 56 of 100 were predicted correctly
# Test Accuracy of class fox : 59.0% where 59 of 100 were predicted correctly
# Test Accuracy of class girl : 32.0% where 32 of 100 were predicted correctly
# Test Accuracy of class hamster : 61.0% where 61 of 100 were predicted correctly
# Test Accuracy of class house : 52.0% where 52 of 100 were predicted correctly
# Test Accuracy of class kangaroo : 44.0% where 44 of 100 were predicted correctly
# Test Accuracy of class keyboard : 68.0% where 68 of 100 were predicted correctly
# Test Accuracy of class lamp : 44.0% where 44 of 100 were predicted correctly
# Test Accuracy of class lawn_mower : 77.0% where 77 of 100 were predicted correctly
# Test Accuracy of class leopard : 53.0% where 53 of 100 were predicted correctly
# Test Accuracy of class lion : 60.0% where 60 of 100 were predicted correctly
# Test Accuracy of class lizard : 31.0% where 31 of 100 were predicted correctly
# Test Accuracy of class lobster : 42.0% where 42 of 100 were predicted correctly
# Test Accuracy of class man : 40.0% where 40 of 100 were predicted correctly
# Test Accuracy of class maple_tree : 68.0% where 68 of 100 were predicted correctly
# Test Accuracy of class motorcycle : 89.0% where 89 of 100 were predicted correctly
# Test Accuracy of class mountain : 82.0% where 82 of 100 were predicted correctly
# Test Accuracy of class mouse : 26.0% where 26 of 100 were predicted correctly
# Test Accuracy of class mushroom : 55.0% where 55 of 100 were predicted correctly
# Test Accuracy of class oak_tree : 70.0% where 70 of 100 were predicted correctly
# Test Accuracy of class orange : 90.0% where 90 of 100 were predicted correctly
# Test Accuracy of class orchid : 71.0% where 71 of 100 were predicted correctly
# Test Accuracy of class otter : 16.0% where 16 of 100 were predicted correctly
# Test Accuracy of class palm_tree : 71.0% where 71 of 100 were predicted correctly
# Test Accuracy of class pear : 64.0% where 64 of 100 were predicted correctly
# Test Accuracy of class pickup_truck : 68.0% where 68 of 100 were predicted correctly
# Test Accuracy of class pine_tree : 55.0% where 55 of 100 were predicted correctly
# Test Accuracy of class plain : 86.0% where 86 of 100 were predicted correctly
# Test Accuracy of class plate : 59.0% where 59 of 100 were predicted correctly
# Test Accuracy of class poppy : 61.0% where 61 of 100 were predicted correctly
# Test Accuracy of class porcupine : 60.0% where 60 of 100 were predicted correctly
# Test Accuracy of class possum : 39.0% where 39 of 100 were predicted correctly
# Test Accuracy of class rabbit : 36.0% where 36 of 100 were predicted correctly
# Test Accuracy of class raccoon : 57.0% where 57 of 100 were predicted correctly
# Test Accuracy of class ray : 49.0% where 49 of 100 were predicted correctly
# Test Accuracy of class road : 86.0% where 86 of 100 were predicted correctly
# Test Accuracy of class rocket : 72.0% where 72 of 100 were predicted correctly
# Test Accuracy of class rose : 55.0% where 55 of 100 were predicted correctly
# Test Accuracy of class sea : 81.0% where 81 of 100 were predicted correctly
# Test Accuracy of class seal : 42.0% where 42 of 100 were predicted correctly
# Test Accuracy of class shark : 50.0% where 50 of 100 were predicted correctly
# Test Accuracy of class shrew : 45.0% where 45 of 100 were predicted correctly
# Test Accuracy of class skunk : 77.0% where 77 of 100 were predicted correctly
# Test Accuracy of class skyscraper : 76.0% where 76 of 100 were predicted correctly
# Test Accuracy of class snail : 51.0% where 51 of 100 were predicted correctly
# Test Accuracy of class snake : 36.0% where 36 of 100 were predicted correctly
# Test Accuracy of class spider : 55.0% where 55 of 100 were predicted correctly
# Test Accuracy of class squirrel : 29.0% where 29 of 100 were predicted correctly
# Test Accuracy of class streetcar : 69.0% where 69 of 100 were predicted correctly
# Test Accuracy of class sunflower : 87.0% where 87 of 100 were predicted correctly
# Test Accuracy of class sweet_pepper : 46.0% where 46 of 100 were predicted correctly
# Test Accuracy of class table : 52.0% where 52 of 100 were predicted correctly
# Test Accuracy of class tank : 72.0% where 72 of 100 were predicted correctly
# Test Accuracy of class telephone : 60.0% where 60 of 100 were predicted correctly
# Test Accuracy of class television : 63.0% where 63 of 100 were predicted correctly
# Test Accuracy of class tiger : 56.0% where 56 of 100 were predicted correctly
# Test Accuracy of class tractor : 69.0% where 69 of 100 were predicted correctly
# Test Accuracy of class train : 63.0% where 63 of 100 were predicted correctly
# Test Accuracy of class trout : 70.0% where 70 of 100 were predicted correctly
# Test Accuracy of class tulip : 45.0% where 45 of 100 were predicted correctly
# Test Accuracy of class turtle : 29.0% where 29 of 100 were predicted correctly
# Test Accuracy of class wardrobe : 89.0% where 89 of 100 were predicted correctly
# Test Accuracy of class whale : 59.0% where 59 of 100 were predicted correctly
# Test Accuracy of class willow_tree : 50.0% where 50 of 100 were predicted correctly
# Test Accuracy of class wolf : 51.0% where 51 of 100 were predicted correctly
# Test Accuracy of class woman : 29.0% where 29 of 100 were predicted correctly
# Test Accuracy of class worm : 63.0% where 63 of 100 were predicted correctly
#
# Test Accuracy : 57.26% where 5726 of 10000 were predicted correctly

# %% [markdown]
# ##Mapas de calor de la primera capa convolucional

# %%
weight2 = []
for x in model.state_dict()["conv1.0.weight"]:
    for y in x:
        weight = y
        weight = weight / weight.max()
        weight = np.clip(weight, 0, 1)
        weight2.append(weight)


fig, axis = plt.subplots(nrows=5, ncols=6, figsize=(10, 10))


for ax, a in zip(axis.ravel(), range(30)):
    ax.imshow(weight2[a])

# %% [markdown]
# ##Mapas de calor de la segunda capa convolucional
#
# Como son demasiadas capas solo se plotearan estas 2 debido a que repsentan una base coherente para las demas

# %%
weight4 = []
for x in model.state_dict()["conv2.0.weight"]:
    for y in x:
        weight3 = y
        weight3 = weight3 / weight3.max()
        weight3 = np.clip(weight3, 0, 1)
        weight4.append(weight3)

fig, axis = plt.subplots(nrows=5, ncols=12, figsize=(40, 40))

for ax, a in zip(axis.ravel(), range(60)):
    ax.imshow(weight4[a])

# %% [markdown]
# ##Conclusiones
#
# EL modelo es exitoso para los valores solicitados, se probo con varias funciones de optimizacion como BCE y Adam pero niguna lograba converger a valores superiores a 54% por lo cual se decidio utilizar el stochastic gradient descent para poder converger a valores mayores para un modelo de Resnet9
#
# Es necesario tambien conocer que la precision peude ser mejorada si se aumentan las capas convolucionales, se utiliza un modelo mas extenso o aun mas imporante si se consideran muchas mas tiempos de entrenamiento.
